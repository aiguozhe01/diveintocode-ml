# %%
"""問題１"""
import numpy as np

# -50から50まで0.1間隔のxを表すndarray
x = np.arange(-50, 50.1, 0.1)
y = ((1/2) * x) + 1

# print(x)
# print(y)

# %%
"""問題２"""
data1 = x.reshape(1001, 1)
# data1 = x.reshape(-1, 1)
data2 = y.reshape(1001, 1)
# data2 = y,reshape(-1, 1)

concat_data = np.concatenate((data1, data2), axis=1)
# concat_data = np.hstack([data1, data2])
print(concat_data.shape)
# Out:
# (1001, 2)

# %%
"""問題３"""
# x_gradient = np.gradient(x)
# dx = xy[1: ,0]
# y_gradient = np.gradient(y)

d_1_a = data1[1:]
d_1_b = data1[:-1]
d_2_a = data2[1:]
d_2_b = data2[:-1]

x_gradient = d_1_b - d_1_a
y_gradient = d_2_b - d_2_a

total_gradient = (y_gradient / x_gradient)
print(total_gradient)
# Out:
# [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
# ...

# %%
"""問題４"""
